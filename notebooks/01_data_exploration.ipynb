# %% [markdown]
# # 01 - Data Exploration
#
# **Mục tiêu:**
# - Hiểu cấu trúc dataset LFW
# - Thống kê: số identities, số ảnh/identity, phân phối
# - Visualize vài ảnh mẫu
# - Kiểm tra chất lượng ảnh (resolution, blur, etc.)

# %%
import sys
sys.path.append('..')

from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ## TODO
#
# - [ ] Load dataset from `data/raw/lfw/`
# - [ ] Count identities và ảnh/identity
# - [ ] Plot histogram số ảnh/identity
# - [ ] Hiển thị grid 16 ảnh mẫu
# - [ ] Kiểm tra image sizes
