# %% [markdown]
# # 02 - Embedding Visualization
#
# **Mục tiêu:**
# - Visualize embedding space bằng t-SNE / UMAP
# - Kiểm tra xem embeddings có tách biệt theo identity không
# - So sánh embeddings của ảnh masked vs unmasked cho cùng 1 người

# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
# from src.utils.visualization import plot_embeddings_2d

# %% [markdown]
# ## TODO
#
# - [ ] Load embeddings đã extract từ `data/embeddings/`
# - [ ] Chọn 10-20 identities có nhiều ảnh nhất
# - [ ] t-SNE -> 2D
# - [ ] Plot với màu theo identity
# - [ ] So sánh: same person - masked vs unmasked có gần nhau không?
